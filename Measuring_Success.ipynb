# %%
"Importing useful modules"
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
#Articles = pandas.read_csv('articles.csv')
Journals = pandas.read_csv('journals.csv', engine='python')
Articles = pandas.read_csv('articles.csv', engine='python')

# %%
"Making a list of all unique journal names and their ISSN numbers from the journals.csv file"
Journal_Name = Journals["Title"]
ISSN = Journals["Print-ISSN"]
CiteScore = Journals["CiteScore"]

length = len(Journal_Name)
Journal_Dict = {}
Journ_Succ = {}

# %%
for i in range(length):
    rank = CiteScore[i]
    
    if i == length-1:
        Journal_Dict[ISSN[i]] = Journal_Name[i]
        Journ_Succ[ISSN[i]] = rank
    elif Journal_Name[i] == Journal_Name[i+1]:
        continue
    else:
        Journal_Dict[ISSN[i]] = Journal_Name[i]
        Journ_Succ[ISSN[i]] = rank

# %% [markdown]
# # Parsing articles.csv

# %%
Title = Articles["Title"] #list of Article titles
Art_ISSN = Articles["ISSN"] #list of corresponding ISSN numbers for the articles
Art_Success = []

# %%
Cite = Articles["Cited by"]
Year = Articles["Year"]

# %%
NumA = len(Title)
CurrentYear = 2019
weight = 0.5
for a in range(NumA):
    try:
        ID = Art_ISSN[a]
        J_Succ = Journ_Succ[ID]
    except:
        Art_Success.append('Journal Not Found')
        continue
    
    Succ = float(Cite[a])+(CurrentYear-float(Year[a]))*weight
    Art_Success.append(Succ + J_Succ)
# Out:
# [3.7, 2.49, 5.66, 5.91, 2.96, 0.5, 5.86, 2.3, 2.74, 'Journal Not Found', 5.03, 'Journal Not Found', 9.62, 4.86, 3.85, 1.4300000000000002, 4.86, 4.86, 12.91, 5.86, 4.86, 5.86, 'Journal Not Found', 5.86, 13.91, 9.36, 13.91, 4.86, 4.86, 4.86, 4.86, 13.91, 1.77, 17.91, 1.77, 4.86, 14.91, 'Journal Not Found', 14.91, 4.86, 4.86, 4.86, 5.86, 5.36, 5.86, 4.86, 4.86, 5.86, 5.86, 4.86, 2.5, 5.49, 15.91, 9.86, 5.86, 16.91, 4.86, 4.86, 3.87, 13.91, 2.71, 4.86, 15.91, 15.91, 2.58, 4.86, 4.86, 6.86, 1.2, 5.36, 4.86, 4.86, 12.91, 6.86, 4.86, 4.86, 2.74, 6.36, 4.86, 5.5, 12.91, 12.91, 13.91, 12.91, 4.86, 4.86, 6.96, 16.91, 14.91, 6.86, 21.91, 12.91, 4.86, 4.86, 'Journal Not Found', 'Journal Not Found', 4.86, 3.85, 4.86, 14.91, 7.86, 5.86, 4.86, 12.91, 4.86, 13.91, 7.86, 4.86, 12.91, 12.91, 5.86, 4.86, 13.91, 14.91, 14.91, 14.91, 4.86, 4.86, 25.91, 5.86, 12.91, 6.86, 12.91, 12.91, 'Journal Not Found', 4.86, 12.91, 4.86, 7.86, 13.91, 2.5, 'Journal Not Found', 14.91, 13.91, 17.91, 1.5, 'Journal Not Found', 12.91, 12.91, 13.91, 5.86, 16.91, 13.91, 3.09, 3.09, 3.0, 2.04, 6.14, 'Journal Not Found', 4.46, 4.04, 3.73, 4.86, 12.81, 4.16, 10.1, 'Journal Not Found', 3.16, 2.3, 2.67, 3.79, 'Journal Not Found', 'Journal Not Found', 4.02, 3.09, 'Journal Not Found', 2.98, 6.09, 3.09, 7.82, 3.92, 2.58, 7.82, 12.91, 12.91, 2.79, 5.390000000000001, 4.390000000000001, 3.04, 3.13, 2.62, 4.3100000000000005, 'Journal Not Found', 1.47, 3.65, 4.83, 1.72, 3.09, 'Journal Not Found', 9.07, 3.51, 3.51, 2.71, 4.02, 1.99, 3.51, 2.27, 1.59, 'Journal Not Found', 8.17, 4.18, 8.78, 4.77, 4.26, 'Journal Not Found', 5.36, 6.68, 'Journal Not Found', 3.22, 3.02, 3.09, 3.51, 'Journal Not Found', 4.83, 12.91, 4.779999999999999, 7.82, 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 1.5, 'Journal Not Found', 1.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 3.16, 4.6, 2.67, 3.09, 0.5, 'Journal Not Found', 3.09, 1.81, 4.85, 3.71, 2.24, 6.14, 4.16, 4.93, 'Journal Not Found', 3.93, 3.67, 6.14, 11.81, 2.24, 6.76, 2.2, 3.06, 3.06, 2.89, 4.99, 1.5, 'Journal Not Found', 7.38, 4.279999999999999, 2.67, 3.16, 5.66, 4.68, 5.66, 7.38, 9.27, 5.27, 4.95, 5.34, 2.67, 0.5, 'Journal Not Found', 1.5, 'Journal Not Found', 2.4299999999999997, 6.66, 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 3.09, 4.16, 4.68, 0.5, 'Journal Not Found', 2.25, 2.3, 2.85, 'Journal Not Found', 'Journal Not Found', 2.85, 0.5, 'Journal Not Found', 7.15, 0.54, 5.74, 3.51, 1.33, 7.04, 8.34, 3.51, 4.85, 4.859999999999999, 4.09, 4.54, 4.89, 3.86, 3.09, 'Journal Not Found', 9.61, 3.09, 4.33, 'Journal Not Found', 4.2, 3.09, 3.99, 3.86, 2.68, 4.18, 2.92, 4.89, 2.77, 4.74, 5.68, 6.5, 3.62, 4.529999999999999, 3.51, 5.02, 6.7, 2.53, 6.529999999999999, 5.08, 2.2, 7.7, 6.31, 2.16, 5.27, 12.85, 3.56, 2.52, 3.09, 'Journal Not Found', 4.75, 6.31, 5.08, 11.42, 5.65, 'Journal Not Found', 10.07, 7.63, 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 0.5, 'Journal Not Found', 'Journal Not Found', 3.09, 2.62, 2.87, 7.38, 2.81, 5.12, 3.79, 3.06, 2.67, 5.94, 2.5, 'Journal Not Found', 2.96, 5.15, 'Journal Not Found', 56.58, 4.38, 3.93, 4.99, 8.940000000000001, 12.5, 5.71, 1.5, 'Journal Not Found', 4.38, 2.91, 5.34, 2.31, 'Journal Not Found', 3.77, 8.82, 5.57, 3.33, 8.030000000000001, 6.59, 3.88, 3.93, 2.38, 4.07, 'Journal Not Found', 3.45, 5.27, 6.02, 4.73, 3.51, 2.6, 4.16, 7.9, 7.02, 'Journal Not Found', 1.61, 3.19, 6.68, 2.96, 3.51, 9.09, 5.2, 4.56, 7.9, 4.58, 12.309999999999999, 2.46, 3.88, 3.4, 9.58, 6.6, 9.71, 2.62, 2.98, 5.44, 'Journal Not Found', 'Journal Not Found', 3.68, 1.78, 5.57, 'Journal Not Found', 4.6, 3.0, 6.85, 3.51, 4.85, 2.91, 5.08, 9.26, 3.26, 6.35, 7.1, 2.66, 'Journal Not Found', 4.83, 6.89, 3.56, 3.37, 6.44, 4.62, 'Journal Not Found', 'Journal Not Found', 5.04, 2.72, 18.75, 5.02, 12.17, 6.02, 0.5, 'Journal  ...

# %%
import csv
filename = 'Article_Success.csv'

# %%
NumA = len(Title)

with open(filename, mode='w') as f:
    fieldnames = ['Title','Success']
    writer = csv.writer(f, delimiter=',')
    writer.writerow(fieldnames)
    for n in range(NumA):
        List = [Title[n],Art_Success[n]]
        try:
            writer.writerow(List)
        except:
            continue
